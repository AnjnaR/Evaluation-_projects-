# %% [markdown]
# BASEBALL
# Baseball statistics play an important role in evaluating the progress of a player or team.
#
# Since the flow of a baseball game has natural breaks to it, and normally players act individually rather than performing in clusters, the sport lends itself to easy record-keeping and statistics. Statistics have been kept for professional baseball since the creation of the National League and American League, now part of Major League Baseball.
#
# Many statistics are also available from outside Major League Baseball, from leagues such as the National Association of Professional Base Ball Players and the Negro leagues, although the consistency of whether these records were kept, of the standards with respect to which they were calculated, and of their accuracy has varied.
#
# Data Description
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# Loading the Dataset

# %%
import pandas as pd
import numpy as np

path ='https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv'
df= pd.read_csv(path)

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# Details About the Columns
# 1. W
#
# This column shows the Total no of wins of each team
#
# 2. R
#
# This column shows the Runs scored: number of times a player crosses home plate
#
# 3. AB
#
# This column shows the At bat: plate appearances, not including bases on balls, being hit by pitch, sacrifices, interference, or obstruction
#
# 4. H
#
# This column shows the Hit: reaching base because of a batted, fair ball without error by the defense
#
# 5. 2B
#
# This column shows the Double: hits on which the batter reaches second base safely without the contribution of a fielding error
#
# 6. 3B
#
# This column shows the Triple: hits on which the batter reaches third base safely without the contribution of a fielding error
#
# 7. HR
#
# This column shows the Home runs: hits on which the batter successfully touched all four bases, without the contribution of a fielding error
#
# 8. BB
#
# This column shows the Base on balls (also called a "walk"): times pitching four balls, allowing the batter to take first base
#
# 9. SO
#
# This column shows the Plate appearances per strikeout: number of times a batter strikes out to their plate appearance
#
# 10. RA
#
# This column shows the Run average: number of runs allowed times nine divided by innings pitched
#
# 11. ER
#
# This column shows the Earned run: number of runs that did not occur as a result of errors or passed balls
#
# 12. ERA
#
# This column shows the Earned run average: total number of earned runs (see "ER" above), multiplied by 9, divided by innings pitched
#
# 13. CG
#
# This column shows the Complete game: number of games where player was the only pitcher for their team
#
# 14. SHO
#
# This column shows the Shutout: number of complete games pitched with no runs allowed
#
# 15. SV
#
# This column shows the Save opportunity: When a pitcher 1) enters the game with a lead of three or fewer runs and pitches at least one inning, 2) enters the game with the potential tying run on base, at bat, or on deck, or 3) pitches three or more innings with a lead and is credited with a save by the official scorer
#
# 16. E
#
# This column shows the Errors: number of times a fielder fails to make a play he should have made with common effort, and the offense benefits as a result

# %% [markdown]
# Checking for the Columns containing Null , Blank Or Empty Values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# We can see that there arte no Null Nlank Or Empty Values present in the Datset
#
# Checking and Transforming the Data types of the Columns To Same DataTypes for Better Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
sum(df.duplicated())
# Out:
# 0

# %% [markdown]
# No Duplicate values are Present
#
# EDA

# %%
sns.lineplot(x='W',y='R',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='R'>

# %%
sns.barplot(data=df, x="W", y="AB")
# Out:
# <AxesSubplot:xlabel='W', ylabel='AB'>

# %%
df.plot.hexbin(x='W', y='H', gridsize=15)
# Out:
# <AxesSubplot:xlabel='W', ylabel='H'>

# %%
df.plot.scatter(x='R',y='2B')
# Out:
# <AxesSubplot:xlabel='R', ylabel='2B'>

# %%
sns.displot(df['3B'])

# %%
sns.countplot(df['HR'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='HR', ylabel='count'>

# %%
sns.displot(df['BB'],kind='kde',color='blue')

# %%
sns.countplot(y=df['SO'])
# Out:
# <AxesSubplot:xlabel='count', ylabel='SO'>

# %%
df.plot.hexbin(x='W', y='SB', gridsize=15)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SB'>

# %%
sns.lineplot(x='W',y='RA',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='RA'>

# %%
df.plot.scatter(x='R',y='ER')
# Out:
# <AxesSubplot:xlabel='R', ylabel='ER'>

# %%
sns.displot(df['ERA'],kind='kde',color='blue')

# %%
sns.barplot(data=df, x="W", y="CG")
# Out:
# <AxesSubplot:xlabel='W', ylabel='CG'>

# %%
sns.barplot(data=df, x="W", y="SHO")
# Out:
# <AxesSubplot:xlabel='W', ylabel='SHO'>

# %%
sns.lineplot(x='W',y='SV',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SV'>

# %%
sns.lineplot(x='W',y='E',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='E'>

# %%
df.plot.line(subplots = True, figsize=(20,20))
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %%
df.plot.bar(subplots= True,stacked= False, figsize=(20,30))
# Out:
# array([<AxesSubplot:title={'center':'W'}>,
#        <AxesSubplot:title={'center':'R'}>,
#        <AxesSubplot:title={'center':'AB'}>,
#        <AxesSubplot:title={'center':'H'}>,
#        <AxesSubplot:title={'center':'2B'}>,
#        <AxesSubplot:title={'center':'3B'}>,
#        <AxesSubplot:title={'center':'HR'}>,
#        <AxesSubplot:title={'center':'BB'}>,
#        <AxesSubplot:title={'center':'SO'}>,
#        <AxesSubplot:title={'center':'SB'}>,
#        <AxesSubplot:title={'center':'RA'}>,
#        <AxesSubplot:title={'center':'ER'}>,
#        <AxesSubplot:title={'center':'ERA'}>,
#        <AxesSubplot:title={'center':'CG'}>,
#        <AxesSubplot:title={'center':'SHO'}>,
#        <AxesSubplot:title={'center':'SV'}>,
#        <AxesSubplot:title={'center':'E'}>], dtype=object)

# %%
df.hist(figsize=(15,30),layout=(9,4),bins=15,legend=True)
plt.show()

# %%
df.plot.line(figsize=(10,8))
# Out:
# <AxesSubplot:>

# %%
#COORELATION
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA -0.819600 -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# CG   0.080533  0.232042 -0.080876  0.147955  0.306675 -0.065898  0.156502
# SHO  0.471805 -0.103274 -0.197321 -0.145559  0.057998 -0.041396 -0.019119
# SV   0.666530 -0.096380 -0.106367 -0.130371  0.171576 -0.142370 -0.028540
# E   -0.089485 -0.023262  0.316743 -0.033173  0.105754  0.126678 -0.207597
#
#            BB        SO        SB        RA        ER       ERA        CG  \
# W    0.484342  0.111850 -0.157234 -0.812952 -0.809435 -0.819600  0.080533
# R    0.402452 -0.054726  0.081367 -0.041623 -0.041245 -0.049281  0.232042
# AB  -0.136414 -0.106022  0.372618  0.316010  0.309686  0.255551 -0.080876
# H   -0.118281 -0.398830  0.413444  0.224324  0.252489  0.231172  0.147955
# 2B   0.302700 -0.150752  0.195027 -0.218160 -0.235531 -0.254854  0.306675
# 3B  -0.454949 -0.141196  0.457437  0.314125  0.340225  0.330951 -0.065898
# HR   0.425691  0.359923 -0.136567 -0.103903 -0.085922 -0.090917  0.156502
# BB   1.000000  0.233652 -0.098347 -0.416445 -0.452663 -0.459832  0.462478
# SO   0.233652  1.000000  0.030968 -0.129745 -0.161612 -0.180368 -0.093418
# SB  -0.098347  0.030968  1.000000  0.132290  0.143068  0.126063 -0.020783
# RA  -0.416445 -0.129745  0.132290  1.000000  0.991018  0.986674 -0.016659
# ER  -0.452663 -0.161612  0.143068  0.991018  1.000000  0.997248 -0.020221
# ERA -0.459832 -0.180368  0.126063  0.986674  0.997248  1.000000 -0.009856
# CG   0.462478 -0.093418 -0.020783 -0.016659 -0.020221 -0.009856  1.000000
# SHO  0.426004  0.237721 -0.106563 -0.636862 -0.630192 -0.630833  0.241676
# SV   0.099445  0.126297 -0.183418 -0.616224 -0.589663 -0.607005 -0.367766
# E   -0.075685  0.155133  0.079149  0.198996  0.136921  0.113137 -0.140047
#
#           SHO        SV         E
# W    0.471805  0.666530 -0.089485
# R   -0.103274 -0.096380 -0.023262
# AB  -0.197321 -0.106367  0.316743
# H   -0.145559 -0.130371 -0.033173
# 2B   0.057998  0.171576  0.105754
# 3B  -0.041396 -0.142370  0.126678
# HR  -0.019119 -0.028540 -0.207597
# BB   0.426004  0.099445 -0.075685
# SO   0.237721  0.126297  0.155133
# SB  -0.106563 -0.183418  0.079149
# RA  -0.636862 -0.616224  0.198996
# ER  -0.630192 -0.589663  0.136921
# ERA -0.630833 -0.607005  0.113137
# CG   0.241676 -0.367766 -0.140047
# SHO  1.000000  0.221639 -0.115716
# SV   0.221639  1.000000 -0.025636
# E   -0.115716 -0.025636  1.000000

# %%
df.corr()['W'].sort_values()
# Out:
# ERA   -0.819600
# RA    -0.812952
# ER    -0.809435
# 3B    -0.251118
# SB    -0.157234
# E     -0.089485
# AB    -0.087947
# H      0.037612
# CG     0.080533
# SO     0.111850
# HR     0.307407
# 2B     0.427797
# R      0.430751
# SHO    0.471805
# BB     0.484342
# SV     0.666530
# W      1.000000
# Name: W, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,linecolor="black", fmt='.2f')
# Out:
# <AxesSubplot:>

# %%
#Descriptive Statistics
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %%
plt.figure(figsize=(15,7))
sns.heatmap(round(df.describe()[1:].transpose(),2), annot=True, linewidths=0.5,linecolor="black", fmt='f')
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
#Checking Data To Remove Skewness
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %%
df.plot(kind='density', subplots=True, layout=(5,4), sharex=False, legend=True, fontsize=1, figsize=(22,12))
plt.show()

# %%
from sklearn.preprocessing import power_transform
x_new=power_transform(df,method='yeo-johnson')

df=pd.DataFrame(x_new,columns=df.columns)
# Out:
# C:\Users\lenovo\AppData\Roaming\Python\Python38\site-packages\sklearn\preprocessing\_data.py:3253: RuntimeWarning: divide by zero encountered in log
#   loglike = -n_samples / 2 * np.log(x_trans.var())

# %%
df.skew()
# Out:
# W     -0.027204
# R      0.000000
# AB     0.000000
# H      0.000000
# 2B    -0.035315
# 3B    -0.072933
# HR    -0.000065
# BB    -0.007760
# SO     0.041170
# SB    -0.010455
# RA    -0.008082
# ER    -0.001940
# ERA    0.001746
# CG    -0.059785
# SHO    0.006560
# SV     0.000836
# E      0.063909
# dtype: float64

# %%
sns.heatmap(df.corr()[['W']].sort_values(by='W',ascending= False ), vmin=-1,vmax=1,annot= True ,cmap='BrBG')
# Out:
# <AxesSubplot:>

# %%
#Outliers Checking
import warnings
warnings.filterwarnings('ignore')
df.plot(kind='box',subplots=True, layout=(6,3), figsize=[30,20])
# Out:
# W         AxesSubplot(0.125,0.772143;0.227941x0.107857)
# R      AxesSubplot(0.398529,0.772143;0.227941x0.107857)
# AB     AxesSubplot(0.672059,0.772143;0.227941x0.107857)
# H         AxesSubplot(0.125,0.642714;0.227941x0.107857)
# 2B     AxesSubplot(0.398529,0.642714;0.227941x0.107857)
# 3B     AxesSubplot(0.672059,0.642714;0.227941x0.107857)
# HR        AxesSubplot(0.125,0.513286;0.227941x0.107857)
# BB     AxesSubplot(0.398529,0.513286;0.227941x0.107857)
# SO     AxesSubplot(0.672059,0.513286;0.227941x0.107857)
# SB        AxesSubplot(0.125,0.383857;0.227941x0.107857)
# RA     AxesSubplot(0.398529,0.383857;0.227941x0.107857)
# ER     AxesSubplot(0.672059,0.383857;0.227941x0.107857)
# ERA       AxesSubplot(0.125,0.254429;0.227941x0.107857)
# CG     AxesSubplot(0.398529,0.254429;0.227941x0.107857)
# SHO    AxesSubplot(0.672059,0.254429;0.227941x0.107857)
# SV           AxesSubplot(0.125,0.125;0.227941x0.107857)
# E         AxesSubplot(0.398529,0.125;0.227941x0.107857)
# dtype: object

# %%
#IQR Proximity Rule
#Z - Score Technique

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape
# Out:
# (30, 17)

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 0

# %% [markdown]
# # Feature Engineering ( Variantion Inflation Factor )

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
df.corr()
# Out:
#             W   R  AB   H        2B        3B        HR        BB        SO  \
# W    1.000000 NaN NaN NaN  0.433093 -0.247935  0.326265  0.478887  0.124063
# R         NaN NaN NaN NaN       NaN       NaN       NaN       NaN       NaN
# AB        NaN NaN NaN NaN       NaN       NaN       NaN       NaN       NaN
# H         NaN NaN NaN NaN       NaN       NaN       NaN       NaN       NaN
# 2B   0.433093 NaN NaN NaN  1.000000  0.204475  0.076143  0.301392 -0.173551
# 3B  -0.247935 NaN NaN NaN  0.204475  1.000000 -0.393924 -0.458272 -0.133889
# HR   0.326265 NaN NaN NaN  0.076143 -0.393924  1.000000  0.417581  0.385912
# BB   0.478887 NaN NaN NaN  0.301392 -0.458272  0.417581  1.000000  0.238514
# SO   0.124063 NaN NaN NaN -0.173551 -0.133889  0.385912  0.238514  1.000000
# SB  -0.164478 NaN NaN NaN  0.236904  0.508077 -0.179200 -0.107299  0.017165
# RA  -0.812840 NaN NaN NaN -0.228612  0.295742 -0.105691 -0.413502 -0.141401
# ER  -0.809025 NaN NaN NaN -0.245781  0.322298 -0.088189 -0.450727 -0.174501
# ERA -0.818894 NaN NaN NaN -0.263350  0.313272 -0.096858 -0.458850 -0.192592
# CG   0.063648 NaN NaN NaN  0.279284 -0.066691  0.194161  0.480102 -0.095856
# SHO  0.459124 NaN NaN NaN  0.066977 -0.047706 -0.027620  0.405895  0.216663
# SV   0.665322 NaN NaN NaN  0.129807 -0.182646  0.019674  0.118506  0.173120
# E   -0.101470 NaN NaN NaN  0.097293  0.102814 -0.145955 -0.067006  0.176769
#
#            SB        RA        ER       ERA        CG       SHO        SV  \
# W   -0.164478 -0.812840 -0.809025 -0.818894  0.063648  0.459124  0.665322
# R         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# AB        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# H         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2B   0.236904 -0.228612 -0.245781 -0.263350  0.279284  0.066977  0.129807
# 3B   0.508077  0.295742  0.322298  0.313272 -0.066691 -0.047706 -0.182646
# HR  -0.179200 -0.105691 -0.088189 -0.096858  0.194161 -0.027620  0.019674
# BB  -0.107299 -0.413502 -0.450727 -0.458850  0.480102  0.405895  0.118506
# SO   0.017165 -0.141401 -0.174501 -0.192592 -0.095856  0.216663  0.173120
# SB   1.000000  0.144945  0.152631  0.136497  0.015024 -0.109000 -0.206638
# RA   0.144945  1.000000  0.990953  0.986544  0.046866 -0.639168 -0.595927
# ER   0.152631  0.990953  1.000000  0.997244  0.045821 -0.634319 -0.568552
# ERA  0.136497  0.986544  0.997244  1.000000  0.054597 -0.635182 -0.585067
# CG   0.015024  0.046866  0.045821  0.054597  1.000000  0.194671 -0.339623
# SHO -0.109000 -0.639168 -0.634319 -0.635182  0.194671  1.000000  0.199496
# SV  -0.206638 -0.595927 -0.568552 -0.585067 -0.339623  0.199496  1.000000
# E    0.117440  0.232580  0.167895  0.140770 -0.086907 -0.206825 -0.018686
#
#             E
# W   -0.101470
# R         NaN
# AB        NaN
# H         NaN
# 2B   0.097293
# 3B   0.102814
# HR  -0.145955
# BB  -0.067006
# SO   0.176769
# SB   0.117440
# RA   0.232580
# ER   0.167895
# ERA  0.140770
# CG  -0.086907
# SHO -0.206825
# SV  -0.018686
# E    1.000000

# %%
x=df.drop('W',axis=1)
y=df['W']
x
y
# Out:
# 0     1.346947
# 1     0.218658
# 2     0.025271
# 3    -0.465574
# 4    -0.665017
# 5     1.162486
# 6     0.600668
# 7     0.025271
# 8    -0.072041
# 9    -0.267936
# 10    0.695214
# 11    0.505745
# 12    0.410440
# 13   -0.465574
# 14   -1.274850
# 15    1.802315
# 16    1.621136
# 17    1.530067
# 18   -1.274850
# 19   -1.691747
# 20    0.883198
# 21    0.218658
# 22   -0.967709
# 23   -1.378263
# 24   -1.797360
# 25    1.069741
# 26    0.314746
# 27   -0.169774
# 28   -0.665017
# 29   -1.274850
# Name: W, dtype: float64

# %%
def vif_calc():
  vif=pd.DataFrame()
  vif["VIF Factor"]=[variance_inflation_factor(x.values,i) for i in range(x.shape[1])]
  vif["features"]=x.columns
  print(vif)

# %%
vif_calc()
# Out:
#     VIF Factor features
# 0          NaN        R
# 1          NaN       AB
# 2          NaN        H
# 3     2.221041       2B
# 4     2.697792       3B
# 5     2.867884       HR
# 6     3.331177       BB
# 7     2.321817       SO
# 8     1.888334       SB
# 9   177.760829       RA
# 10  543.300331       ER
# 11  314.143795      ERA
# 12    2.162372       CG
# 13    3.197808      SHO
# 14    3.518082       SV
# 15    1.711436        E

# %%
x.drop(['ER','ERA'],axis=1,inplace=True)

# %%
vif_calc()
# Out:
#     VIF Factor features
# 0          NaN        R
# 1          NaN       AB
# 2          NaN        H
# 3     1.872458       2B
# 4     2.528202       3B
# 5     1.838484       HR
# 6     2.780222       BB
# 7     1.789207       SO
# 8     1.600073       SB
# 9     3.779498       RA
# 10    1.896671       CG
# 11    2.785027      SHO
# 12    2.125798       SV
# 13    1.318488        E

# %% [markdown]
# # Scaling the Data

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 0.        ,  0.        ,  0.        ,  1.47768528,  1.03310301,
#         -0.76462586, -1.61091476, -2.56989562,  0.93970819, -0.66033096,
#         -0.35984364, -0.78957937,  1.546378  , -0.3349525 ],
#        [ 0.        ,  0.        ,  0.        ,  0.08426878,  1.2033202 ,
#         -0.15858141, -0.50274883,  0.13491294, -0.53969308,  0.17546536,
#         -0.35984364,  0.25177537,  0.36044386, -0.53221128],
#        [ 0.        ,  0.        ,  0.        ,  1.67078208, -0.16026987,
#         -0.68967629,  1.1282937 , -0.90125379,  0.2119555 , -0.67462053,
#          1.99351257, -0.24539345, -0.6075936 , -1.34233137],
#        [ 0.        ,  0.        ,  0.        , -0.84859969, -0.36052064,
#         -0.8790486 , -1.18120722, -0.1896282 , -0.64256433,  0.18951225,
#          1.22010317, -0.51075929, -0.76445333,  0.67852361],
#        [ 0.        ,  0.        ,  0.        ,  0.79218291,  1.61644394,
#         -0.3298501 , -0.20677062,  0.08545863,  0.07962852,  1.6032282 ,
#          1.22010317,  0.25177537, -1.09501024, -0.53221128],
#        [ 0.        ,  0.        ,  0.        ,  1.99850636, -1.4610616 ,
#          1.93785984,  1.7080669 , -0.95796004,  0.29823789, -0.24775668,
#          1.22010317, -0.24539345, -1.26943834, -0.3349525 ],
#        [ 0.        ,  0.        ,  0.        , -0.19855793, -1.22491064,
#          1.46009864,  1.46112104, -0.22866778, -0.91015416,  0.14736005,
#          0.06463007, -2.09932639,  0.71808189,  0.10453866],
#        [ 0.        ,  0.        ,  0.        , -1.55645436, -1.11030224,
#          1.58355136, -0.90445022,  0.80717417, -2.10289743,  0.07702925,
#         -1.72988948, -0.24539345,  0.10460573, -1.61455012],
#        [ 0.        ,  0.        ,  0.        ,  0.1416866 ,  0.130611  ,
#          0.20005848, -0.55919142,  0.59456066,  0.25528505, -0.64604565,
#         -0.90918054,  0.25177537,  1.90547983,  0.26150364],
#        [ 0.        ,  0.        ,  0.        ,  1.09940491,  0.2252559 ,
#          0.00740376,  0.20459864, -0.98625666, -0.4890904 ,  0.9148155 ,
#          0.06463007, -0.24539345, -0.30910856,  0.4090036 ],
#        [ 0.        ,  0.        ,  0.        ,  0.1993895 ,  0.130611  ,
#          0.35550255,  0.63434931, -0.17008409,  0.82545098,  0.63702368,
#          0.71644471, -0.51075929,  0.36044386,  1.57772533],
#        [ 0.        ,  0.        ,  0.        ,  0.1416866 , -0.46273161,
#          1.89193722,  0.34401438,  1.43447471,  1.54360946, -0.99008598,
#          0.71644471,  0.48616028, -0.45590999, -0.63601435],
#        [ 0.        ,  0.        ,  0.        , -1.70115949, -0.9978016 ,
#          0.47670831, -0.57807386, -0.96739644, -1.56087959, -0.17697199,
#         -0.35984364,  0.25177537,  0.48296759,  0.10453866],
#        [ 0.        ,  0.        ,  0.        , -0.74305731, -0.88727666,
#          1.09863616,  0.20459864,  0.85805048, -0.5908464 ,  0.53945546,
#          0.98187374,  0.25177537,  0.36044386,  0.18425403],
#        [ 0.        ,  0.        ,  0.        ,  0.08426878,  1.37061398,
#         -0.50675282,  0.15184177, -1.25783783, -0.14922002,  0.58129235,
#          0.71644471,  0.93134543, -2.47346122,  1.82912694],
#        [ 0.        ,  0.        ,  0.        ,  0.73160797,  0.77187241,
#         -0.84063614,  0.6847765 ,  0.16463355, -0.5908464 , -2.34864635,
#         -0.90918054,  0.93134543,  2.07367378,  0.33638827],
#        [ 0.        ,  0.        ,  0.        ,  0.97564513, -0.36052064,
#         -0.72702035, -0.09789936,  0.71584268,  0.70858172, -1.30770717,
#         -1.72988948,  0.48616028,  1.35421939,  1.69070364],
#        [ 0.        ,  0.        ,  0.        , -0.19855793, -0.06210084,
#          0.3247704 ,  1.66218601,  2.77484406,  0.58895875, -1.13418647,
#          0.98187374,  2.1228587 ,  0.71808189,  1.23106343],
#        [ 0.        ,  0.        ,  0.        , -0.08627816,  0.31882221,
#         -0.54284278, -1.02214896,  0.48388272,  0.12413531,  0.69269686,
#         -0.90918054, -1.08415811, -0.30910856,  1.45599167],
#        [ 0.        ,  0.        ,  0.        , -1.00482997, -0.36052064,
#          0.20005848,  0.51575406,  0.04596732,  1.96311582,  0.92866776,
#         -0.35984364, -0.78957937, -1.09501024, -0.15049335],
#        [ 0.        ,  0.        ,  0.        ,  1.16172142, -1.4610616 ,
#          0.50658869,  0.37858445,  0.39368322, -1.62503782, -1.06208003,
#         -0.90918054,  0.71241788,  0.94096393, -0.3349525 ],
#        [ 0.        ,  0.        ,  0.        , -0.58265234, -1.96666084,
#          0.50658869,  1.22443057,  0.93965496, -1.2533623 , -0.74613259,
#          0.41526799,  0.48616028, -0.16691871, -0.15049335],
#        [ 0.        ,  0.        ,  0.        , -2.02934483,  0.85977161,
#         -1.53428021, -1.77952032, -0.96739644,  1.23258601, -0.13454934,
#         -1.72988948,  0.25177537, -1.09501024, -1.61455012],
#        [ 0.        ,  0.        ,  0.        , -1.30983118, -1.34177482,
#         -2.48513082,  0.0810878 , -1.36917434, -0.5908464 ,  1.01170768,
#          0.06463007, -0.24539345,  0.23438459, -0.15049335],
#        [ 0.        ,  0.        ,  0.        , -0.19855793,  0.5934617 ,
#         -1.1154812 , -1.52765389,  0.23412141,  0.29823789,  1.68527759,
#         -0.90918054, -1.08415811, -1.09501024,  1.49759735],
#        [ 0.        ,  0.        ,  0.        , -0.68986824, -0.46273161,
#          0.79662621,  1.60071179,  0.07557979, -1.13604803, -1.32219722,
#          0.98187374,  2.1228587 ,  0.60212705, -1.90842687],
#        [ 0.        ,  0.        ,  0.        ,  0.73160797,  0.77187241,
#         -0.8790486 , -0.17035471, -0.88231827,  0.50760474, -0.86077652,
#          1.22010317,  1.55042485, -0.16691871, -1.47586961],
#        [ 0.        ,  0.        ,  0.        ,  0.79218291,  1.53515592,
#         -0.22643599,  0.41304265,  0.61473509,  1.9006571 ,  0.35777783,
#         -0.90918054,  0.25177537,  0.23438459, -0.53221128],
#        [ 0.        ,  0.        ,  0.        , -0.84859969,  0.5028866 ,
#         -0.43529176, -0.749579  ,  0.76654332,  0.03471274,  0.60916531,
#         -0.90918054, -1.39754579, -0.16691871,  0.02225134],
#        [ 0.        ,  0.        ,  0.        , -0.08627816,  1.61644394,
#          0.76831413, -1.50694503,  0.3237498 ,  0.6690207 ,  2.16161235,
#          0.41526799, -2.09932639, -0.92680917,  0.26150364]])

# %% [markdown]
# As the Outcome is No. Of Matches Won which is in Integer So we use Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.metrics import r2_score
from sklearn.model_selection import cross_val_score, GridSearchCV
from sklearn.linear_model import Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor
from sklearn.neighbors import KNeighborsRegressor
 

for i in range(1,100):
  x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
  lr=LinearRegression()
  lr.fit(x_train,y_train)
  pred_train=lr.predict(x_train)
  pred_test=lr.predict(x_test)
  print(f"At random state {i},the training accuracy is :- {r2_score(y_train,pred_train)*100}")
  print(f"At random state {i},the testing accuracy is :- {r2_score(y_test,pred_test)*100}")
  print("\n")
# Out:
# At random state 1,the training accuracy is :- 90.6699832963275
# At random state 1,the testing accuracy is :- 46.2958873689519
#
#
# At random state 2,the training accuracy is :- 91.38485297992838
# At random state 2,the testing accuracy is :- -45.893973232655625
#
#
# At random state 3,the training accuracy is :- 90.31093838095843
# At random state 3,the testing accuracy is :- 18.687136228062727
#
#
# At random state 4,the training accuracy is :- 83.29778369397512
# At random state 4,the testing accuracy is :- 83.07875164079913
#
#
# At random state 5,the training accuracy is :- 85.73094862999938
# At random state 5,the testing accuracy is :- 57.4976661686718
#
#
# At random state 6,the training accuracy is :- 86.01806369500994
# At random state 6,the testing accuracy is :- 73.93669772209869
#
#
# At random state 7,the training accuracy is :- 87.6377146215213
# At random state 7,the testing accuracy is :- 23.912562725569742
#
#
# At random state 8,the training accuracy is :- 84.73650003523362
# At random state 8,the testing accuracy is :- 77.7600222438936
#
#
# At random state 9,the training accuracy is :- 87.26510390976601
# At random state 9,the testing accuracy is :- 41.080157415655236
#
#
# At random state 10,the training accuracy is :- 87.30210317307461
# At random state 10,the testing accuracy is :- 10.468747053723181
#
#
# At random state 11,the training accuracy is :- 90.72882209167071
# At random state 11,the testing accuracy is :- 2.9200462802474014
#
#
# At random state 12,the training accuracy is :- 91.46154765363036
# At random state 12,the testing accuracy is :- -142.82866992508247
#
#
# At random state 13,the training accuracy is :- 90.71514593087662
# At random state 13,the testing accuracy is :- 28.625209470743805
#
#
# At random state 14,the training accuracy is :- 85.36222243342647
# At random state 14,the testing accuracy is :- 75.84082202380601
#
#
# At random state 15,the training accuracy is :- 90.53873937924897
# At random state 15,the testing accuracy is :- 11.017919327334269
#
#
# At random state 16,the training accuracy is :- 91.3966145908922
# At random state 16,the testing accuracy is :- 35.58698251798068
#
#
# At random state 17,the training accuracy is :- 86.4704006063372
# At random state 17,the testing accuracy is :- 49.199284667165365
#
#
# At random state 18,the training accuracy is :- 86.25957554467614
# At random state 18,the testing accuracy is :- 49.856212494532414
#
#
# At random state 19,the training accuracy is :- 85.37232464124365
# At random state 19,the testing accuracy is :- 83.02022808672726
#
#
# At random state 20,the training accuracy is :- 88.2415662163497
# At random state 20,the testing accuracy is :- 32.77063231536306
#
#
# At random state 21,the training accuracy is :- 86.06141576531505
# At random state 21,the testing accuracy is :- 70.34306038988478
#
#
# At random state 22,the training accuracy is :- 83.38158905678567
# At random state 22,the testing accuracy is :- 52.587598541386036
#
#
# At random state 23,the training accuracy is :- 86.13075715363942
# At random state 23,the testing accuracy is :- 57.49220252747664
#
#
# At random state 24,the training accuracy is :- 92.26295280835275
# At random state 24,the testing accuracy is :- -463.88065550948215
#
#
# At random state 25,the training accuracy is :- 86.05485975242934
# At random state 25,the testing accuracy is :- 43.3481115188216
#
#
# At random state 26,the training accuracy is :- 85.03730394574185
# At random state 26,the testing accuracy is :- 55.99995322907325
#
#
# At random state 27,the training accuracy is :- 84.06264186847422
# At random state 27,the testing accuracy is :- 88.29792231997288
#
#
# At random state 28,the training accuracy is :- 87.32896589256814
# At random state 28,the testing accuracy is :- 54.98406089082686
#
#
# At random state 29,the training accuracy is :- 85.09918294052572
# At random state 29,the testing accuracy is :- 85.5219287515559
#
#
# At random state 30,the training accuracy is :- 83.05167923253047
# At random state 30,the testing accuracy is :- 84.40500295190051
#
#
# At random state 31,the training accuracy is :- 96.9008456333244
# At random state 31,the testing accuracy is :- -38.80665436477659
#
#
# At random state 32,the training accuracy is :- 84.44154902841964
# At random state 32,the testing accuracy is :- 62.011250014065034
#
#
# At random state 33,the training accuracy is :- 94.22183566926418
# At random state 33,the testing accuracy is :- 39.693041377920935
#
#
# At random state 34,the training accuracy is :- 91.78992724132745
# At random state 34,the testing accuracy is :- 54.798672799758805
#
#
# At random state 35,the training accuracy is :- 91.6882734558116
# At random state 35,the testing accuracy is :- 13.9992211646782
#
#
# At random state 36,the training accuracy is :- 88.2971256613803
# At random state 36,the testing accuracy is :- 30.47597869192301
#
#
# At random state 37,the training accuracy is :- 87.24147723873776
# At random state 37,the testing accuracy is :- 13.875344049283845
#
#
# At random state 38,the training accuracy is :- 86.10858593165668
# At random state 38,the testing accuracy is :- 33.15702513701627
#
#
# At random state 39,the training accuracy is :- 88.27864859458029
# At random state 39,the testing accuracy is :- 63.07556814782982
#
#
# At random state 40,the training accuracy is :- 89.8786817774294
# At random state 40,the testing accuracy is :- 53.320828750724104
#
#
# At random state 41,the training accuracy is :- 87.2600624942129
# At random state 41,the testing accuracy is :- 51.39132931959518
#
#
# At random state 42,the training accuracy is :- 89.67088971602877
# At random state 42,the testing accuracy is :- 64.49494528307878
#
#
# At random state 43,the training accuracy is :- 92.27459158163971
# At random state 43,the testing accuracy is :- -118.6484988504171
#
#
# At random state 44,the training accuracy is :- 85.28700852863065
# At random state 44,the testing accuracy is :- 72.16752749464759
#
#
# At random state 45,the training accuracy is :- 89.46049752704465
# At random state 45,the testing accuracy is :- -0.21184778662965975
#
#
# At random state 46,the training accuracy is :- 86.41915627643898
# At random state 46,the testing accuracy is :- 66.89052392554245
#
#
# At random state 47,the training accuracy is :- 84.56429904650629
# At random state 47,the testing accuracy is :- 81.74541655514602
#
#
# At random state 48,the training accuracy is :- 82.82483280941926
# At random state 48,the testing accuracy is :- 90.95628905321102
#
#
# At random state 49,the training accuracy is :- 87.81250648954331
# At random state 49,the testing accuracy is :- 33.59386527115239
#
#
# At random state 50,the training accuracy is :- 92.86867635824902
# At random state 50,the testing accuracy is :- 45.75584400839222
#
#
# At random state 51,the training accuracy is :- 89.51728139859215
# At random state 51,the testing accuracy is :- 24.832486207971037
#
#
# At random state 52,the training accuracy is :- 91.90809643731238
# At random state 52,the testing accuracy is :- -58.07473200503106
#
#
# At random state 53,the training accuracy is :- 89.75538054584776
# At random state 53,the testing accuracy is :- 8.014678146623167
#
#
# At random state 54,the training accuracy is :- 86.99792188553707
# At random state 54,the testing accuracy is :- 70.14526883329897
#
#
# At random state 55,the training accuracy is :- 90.19741077753594
# At random state 55,the testing accuracy is :- 30.720948086975763
#
#
# At random state 56,the training accuracy is :- 87.50272808506443
# At random state 56,the testing accuracy is :- 48.81817879656031
#
#
# At random state 57,the training accuracy is :- 91.14586160246367
# At random state 57,the testing accuracy is :- -101.21751865364685
#
#
# At random state 58,the training accuracy is :- 88.33253355587762
# At random state 58,the testing accuracy is :- -15.111735873160747
#
#
# At random state 59,the training accuracy is :- 92.38198964065938
# At random state 59,the testing accuracy is :- -1.263011360017896
#
#
# At random state 60,the training accuracy is :- 89.1042615481363
# At random state 60,the testing accuracy is :- 14.297831273719142
#
#
# At random state 61,the training accuracy is :- 90.31631565387663
# At random state 61,the testing accuracy is :- -41.101064587663295
#
#
# At random state 62,the training accuracy is :- 88.54111755296881
# At random state 62,the testing accuracy is :- -36.97863080835848
#
#
# At random state 63,the training accuracy is :- 87.34462230010513
# At random state 63,the testing accuracy is :- 30.944713695221317
#
#
# At random state 64,the training accuracy is :- 84.4888476084741
# At random state 64,the testing accuracy is :- 84.54003305454809
#
#
# At random state 65,the training accuracy is :- 91.73261868938658
# At random state 65,the testing accuracy is :- 37.9132896700291
#
#
# At random state 66,the training accuracy is :- 94.76040676706486
# At random state 66,the testing accuracy is :- -46.810969086559616
#
#
# At random state 67,the training accuracy is :- 86.48825826852243
# At random state 67,the testing accuracy is :- 50.8535012806766
#
#
# At random state 68,the training accuracy is :- 85.32886200150152
# At random state 68,the testing accuracy is :- 75.43660257315597
#
#
# At random state 69,the training accuracy is :- 86.32481166452257
# At random state 69,the testing accuracy is :- 41.91826373799137
#
#
# At random state 70,the training accuracy is :- 88.29188627935814
# At random state 70,the testing accuracy is :- 28.87165547545757
#
#
# At random state 71,the training accuracy is :- 87.14517078368263
# At random state 71,the testing accuracy is :- 35.45998650814792
#
#
# At random state 72,the training accuracy is :- 88.7187317381283
# At random state 72,the testing accuracy is :- 36.589299954302255
#
#
# At random state 73,the training accuracy is :- 82.86042506520188
# At random state 73,the testing accuracy is :- 87.24197650803185
#
#
# At random state 74,the training accuracy is :- 86.46176126860594
# At random state 74,the testing accuracy is :- 68.64900086414923
#
#
# At random state 75,the training accuracy is :- 86.09193695469966
# At random state 75,the testing accuracy is :- 64.92034699970405
#
#
# At random state 76,the training accuracy is :- 90.359689641441
# At random state 76,the testing accuracy is :- 28.91692001985383
#
#
# At random state 77,the training accuracy is :- 91.95151702723757
# At random state 77,the testing accuracy is :- -77.64808206013123
#
#
# At random state 78,the training accuracy is :- 91.20780091959627
# At random state 78,the testing accuracy is :- 21.080442793166288
#
#
# At random state 79,the training accuracy is :- 89.99888316447061
# At random state 79,the testing accuracy is :- 10.017074671442415
#
#
# At random state 80,the training accuracy is :- 88.7227311003134
# At random state 80,the testing accuracy is :- -18.83224059921318
#
#
# At random state 81,the training accuracy is :- 87.57746401325001
# At random state 81,the testing accuracy is :- -472.67008106604715
# At random state 82,the training accuracy is :- 90.26460019193898
# At random state 82,the testing accuracy is :- 61.28773603322247
#
#
# At random state 83,the training accuracy is :- 86.07263125849676
# At random state 83,the testing accuracy is :- 62.00641185482677
#
#
# At random state 84,the training accuracy is :- 87.564711642063
# At random state 84,the testing accuracy is :- 41.03772943349108
#
#
# At random state 85,the training accuracy is :- 87.84945238207399
# At random state 85,the testing accuracy is :- 57.323506904509536
#
#
# At random state 86,the training accuracy is :- 86.05585663250451
# At random state 86,the testing accuracy is :- 45.75436184914623
#
#
# At random state 87,the training accuracy is :- 86.78430342922316
# At random state 87,the testing accuracy is :- 65.85724890248372
#
#
# At random state 88,the training accuracy is :- 88.89444967734794
# At random state 88,the testing accuracy is :- -378.36125587279747
#
#
# At random state 89,the training accuracy is :- 86.55005265703034
# At random state 89,the testing accuracy is :- 36.03218766790272
#
#
# At random state 90,the training accuracy is :- 87.52351017147242
# At random state 90,the testing accuracy is :- 48.647670536213106
#
#
# At random state 91,the training accuracy is :- 85.02361733365804
# At random state 91,the testing accuracy is :- 74.71288438403204
#
#
# At random state 92,the training accuracy is :- 85.14960112732811
# At random state 92,the testing accuracy is :- 70.42612950330737
#
#
# At random state 93,the training accuracy is :- 86.65000799556314
# At random state 93,the testing accuracy is :- 71.08465889828001
#
#
# At random state 94,the training accuracy is :- 87.47136445240497
# At random state 94,the testing accuracy is :- 33.336781922870614
#
#
# At random state 95,the training accuracy is :- 89.04769590309903
# At random state 95,the testing accuracy is :- -115.45915071554246
#
#
# At random state 96,the training accuracy is :- 86.20623384170383
# At random state 96,the testing accuracy is :- 51.83725252861765
#
#
# At random state 97,the training accuracy is :- 87.73568235726844
# At random state 97,the testing accuracy is :- 37.196924989834365
#
#
# At random state 98,the training accuracy is :- 93.69810505071166
# At random state 98,the testing accuracy is :- 9.088246228859099
#
#
# At random state 99,the training accuracy is :- 83.61305808609352
# At random state 99,the testing accuracy is :- 85.67096652162974

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=99)
x.shape
y.shape
# Out:
# (30,)

# %%
x_train.shape
y_train.shape
# Out:
# (24,)

# %%
x_test.shape
y_test.shape
# Out:
# (6,)

# %%
#Decission Tree Regression
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
pred=lr.predict(x)
print("predicted result ",pred)
print('actual result',y_test)
# Out:
# predicted result  [ 0.98143566  0.05904602  0.46149238 -0.72541088 -0.92401441  0.67307286
#   0.59390716 -0.22717649  0.80836629 -0.28788926  0.05315527  0.71706975
#   0.11582242 -0.01416745 -0.79242601  1.8693684   0.6256885   0.83303417
#  -0.89494    -1.22260615  0.87726356  0.18370302 -1.38864315 -1.55036828
#  -1.89179788  1.2486637   0.45240209 -0.19573949 -0.88197676 -1.17386396]
# actual result 23   -1.378263
# 24   -1.797360
# 16    1.621136
# 12    0.410440
# 21    0.218658
# 27   -0.169774
# Name: W, dtype: float64

# %%
print('Error:')
print('Mean Absolute Error :',mean_absolute_error(y_test,pred))
print('Mean Squared Error :',mean_squared_error(y_test,pred))
print('Root mean Squared Error',np.sqrt(mean_squared_error(y_test,pred)))
print('r2 score :',r2_score(y_test,pred)*100)
# Out:
# Error:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-dd50addad28b> in <module>
#       1 print('Error:')
# ----> 2 print('Mean Absolute Error :',mean_absolute_error(y_test,pred))
#       3 print('Mean Squared Error :',mean_squared_error(y_test,pred))
#       4 print('Root mean Squared Error',np.sqrt(mean_squared_error(y_test,pred)))
#       5 print('r2 score :',r2_score(y_test,pred)*100)
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_regression.py in mean_absolute_error(y_true, y_pred, sample_weight, multioutput)
#     189     0.85...
#     190     """
# --> 191     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     192         y_true, y_pred, multioutput
#     193     )
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      92         the dtype argument passed to check_array.
#      93     """
# ---> 94     check_consistent_length(y_true, y_pred)
#      95     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      96     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#
# ~\AppData\Roaming\Python\Python38\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
# --> 332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
#     334             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [6, 30]

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV

parameters = {'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.1, 'random_state': 0}

# %%
ls=Lasso(alpha=0.1,random_state=0)
ls.fit(x_train,y_train)
ls_score_training=ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)
ls_score_training*100
# Out:
# 77.54224573185033

# %%
from sklearn.ensemble import RandomForestRegressor
Rrf=RandomForestRegressor()

parameters = {'criterion':['mse','mae'],'max_features':["auto","sqrt","log2"]}
clf = GridSearchCV(Rrf,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'log2'}

# %%
from sklearn.model_selection import cross_val_score

Rrf= RandomForestRegressor(criterion="mae",max_features="sqrt")
Rrf.fit(x_train,y_train)
Rrf.score(x_train,y_train)
pred_decession = Rrf.predict(x_test)

rfs = r2_score(y_test,pred_decession)
print('R2 Score :',rfs*100)

rfscore = cross_val_score(Rrf,x,y,cv=5)
rfc=rfscore.mean()
print('cross Val Score :',rfc*100)
# Out:
# R2 Score : 56.59487728344941
# cross Val Score : -15.650233183729068

# %%
#Hyper Parameter Tuning
from sklearn.model_selection import GridSearchCV

# Creating Parameter List to pass in Grid SearchCV

parameters = {'max_features': ['auto','sqrt','log2'],
              'max_depth' : [4,5,6,7,8],
              'criterion' :['mse','mae']}

# %%
gcv=GridSearchCV(RandomForestRegressor(),parameters,cv=5,scoring="accuracy")
gcv.fit(x_train,y_train)
gcv.best_params_

# %%
gcv_pred=gcv.best_estimator_.predict(x_test)
r2_score(y_test,gcv_pred)
# Out:
# 0.711462540727168

# %%
#saving the Best Model
import pickle
filename = 'Baseball.pkl'
pickle.dump(aj_project,open(filename,'wb'))
